# %%
# Dependencies
import openweathermapy.core as owm
from citipy import citipy
import random as rd
# Import api_key
from config import api_key

# %%
lat = -180
lng = -90
cities = []
countrycodes = []
finallat = []
finallon = []
for x in range(0,1500):
    lat = rd.randint(-180,180)
    lng = rd.randint(-90,90)
    
    citydata = citipy.nearest_city(lng,lat)
    if citydata.city_name not in cities:
        cities.append(citydata.city_name)
        countrycodes.append(citydata.country_code)
        finallat.append(lat)
        finallon.append(lng)
print(len(cities))
# Out:
# 631

# %%
import requests
citieslat = []
citieslng = []
citiesname = []
countrycode = []
urllist = []
cityidlist = []
templist = []
humlist = []
cloudiness = []
windspeedlist = []
baseurl = "https://api.openweathermap.org/data/2.5/weather?q="
settings = {"units":"imperial","APIID":api_key}

for x in range(len(cities)):
    try:
        url = f"{baseurl}{cities[x]},{countrycodes[x]}&APPID={api_key}"
        print(f"Retrieving data for {cities[x]}, {countrycodes[x]}")
        print(url)
        print("")
        urllist.append(url)
        citydata = requests.get(url).json()
        citieslat.append(citydata['coord']['lat'])
        citieslng.append(citydata['coord']['lon'])
        cityidlist.append(citydata['id'])
        citiesname.append(cities[x])
        countrycode.append(countrycodes[x])
        cloudiness.append(citydata['clouds']['all'])
        windspeedlist.append(citydata['wind']['speed'])
        templist.append(citydata['main']['temp'])
        humlist.append(citydata['main']['humidity'])
    except:
        pass
    #print(citydata)
# Out:
# Retrieving data for tuktoyaktuk, ca
# https://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for punta arenas, cl
# https://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for carnarvon, au
# https://api.openweathermap.org/data/2.5/weather?q=carnarvon,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for ushuaia, ar
# https://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for berlevag, no
# https://api.openweathermap.org/data/2.5/weather?q=berlevag,no&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for sahrak, af
# https://api.openweathermap.org/data/2.5/weather?q=sahrak,af&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for vaini, to
# https://api.openweathermap.org/data/2.5/weather?q=vaini,to&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for asau, tv
# https://api.openweathermap.org/data/2.5/weather?q=asau,tv&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for waddan, ly
# https://api.openweathermap.org/data/2.5/weather?q=waddan,ly&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for port alfred, za
# https://api.openweathermap.org/data/2.5/weather?q=port alfred,za&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for rikitea, pf
# https://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for belle glade, us
# https://api.openweathermap.org/data/2.5/weather?q=belle glade,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for yulara, au
# https://api.openweathermap.org/data/2.5/weather?q=yulara,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for tianmen, cn
# https://api.openweathermap.org/data/2.5/weather?q=tianmen,cn&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for east london, za
# https://api.openweathermap.org/data/2.5/weather?q=east london,za&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for viganello, ch
# https://api.openweathermap.org/data/2.5/weather?q=viganello,ch&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for samusu, ws
# https://api.openweathermap.org/data/2.5/weather?q=samusu,ws&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for talnakh, ru
# https://api.openweathermap.org/data/2.5/weather?q=talnakh,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for albany, au
# https://api.openweathermap.org/data/2.5/weather?q=albany,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for isla mujeres, mx
# https://api.openweathermap.org/data/2.5/weather?q=isla mujeres,mx&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for hovd, mn
# https://api.openweathermap.org/data/2.5/weather?q=hovd,mn&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for thompson, ca
# https://api.openweathermap.org/data/2.5/weather?q=thompson,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for saint anthony, ca
# https://api.openweathermap.org/data/2.5/weather?q=saint anthony,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for abu dhabi, ae
# https://api.openweathermap.org/data/2.5/weather?q=abu dhabi,ae&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for fuerte olimpo, py
# https://api.openweathermap.org/data/2.5/weather?q=fuerte olimpo,py&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for dikson, ru
# https://api.openweathermap.org/data/2.5/weather?q=dikson,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for castro, cl
# https://api.openweathermap.org/data/2.5/weather?q=castro,cl&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for sentyabrskiy, ru
# https://api.openweathermap.org/data/2.5/weather?q=sentyabrskiy,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for sukabumi, id
# https://api.openweathermap.org/data/2.5/weather?q=sukabumi,id&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for beroroha, mg
# https://api.openweathermap.org/data/2.5/weather?q=beroroha,mg&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for bluff, nz
# https://api.openweathermap.org/data/2.5/weather?q=bluff,nz&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for filingue, ne
# https://api.openweathermap.org/data/2.5/weather?q=filingue,ne&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for jamestown, sh
# https://api.openweathermap.org/data/2.5/weather?q=jamestown,sh&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for bolsheustikinskoye, ru
# https://api.openweathermap.org/data/2.5/weather?q=bolsheustikinskoye,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for tessalit, ml
# https://api.openweathermap.org/data/2.5/weather?q=tessalit,ml&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for illoqqortoormiut, gl
# https://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut,gl&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for namibe, ao
# https://api.openweathermap.org/data/2.5/weather?q=namibe,ao&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for meyungs, pw
# https://api.openweathermap.org/data/2.5/weather?q=meyungs,pw&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for belushya guba, ru
# https://api.openweathermap.org/data/2.5/weather?q=belushya guba,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for thinadhoo, mv
# https://api.openweathermap.org/data/2.5/weather?q=thinadhoo,mv&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for tonantins, br
# https://api.openweathermap.org/data/2.5/weather?q=tonantins,br&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kahului, us
# https://api.openweathermap.org/data/2.5/weather?q=kahului,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for san jose de guanipa, ve
# https://api.openweathermap.org/data/2.5/weather?q=san jose de guanipa,ve&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kodiak, us
# https://api.openweathermap.org/data/2.5/weather?q=kodiak,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for hobart, au
# https://api.openweathermap.org/data/2.5/weather?q=hobart,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for diego de almagro, cl
# https://api.openweathermap.org/data/2.5/weather?q=diego de almagro,cl&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for manyana, bw
# https://api.openweathermap.org/data/2.5/weather?q=manyana,bw&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for mayo, ca
# https://api.openweathermap.org/data/2.5/weather?q=mayo,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for suhbaatar, mn
# https://api.openweathermap.org/data/2.5/weather?q=suhbaatar,mn&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for chuy, uy
# https://api.openweathermap.org/data/2.5/weather?q=chuy,uy&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for adrar, dz
# https://api.openweathermap.org/data/2.5/weather?q=adrar,dz&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for andenes, no
# https://api.openweathermap.org/data/2.5/weather?q=andenes,no&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for zhoucheng, cn
# https://api.openweathermap.org/data/2.5/weather?q=zhoucheng,cn&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for mataura, pf
# https://api.openweathermap.org/data/2.5/weather?q=mataura,pf&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for nikolskoye, ru
# https://api.openweathermap.org/data/2.5/weather?q=nikolskoye,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for krasnyy bogatyr, ru
# https://api.openweathermap.org/data/2.5/weather?q=krasnyy bogatyr,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for valparaiso, cl
# https://api.openweathermap.org/data/2.5/weather?q=valparaiso,cl&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for hilo, us
# https://api.openweathermap.org/data/2.5/weather?q=hilo,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for iqaluit, ca
# https://api.openweathermap.org/data/2.5/weather?q=iqaluit,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for atuona, pf
# https://api.openweathermap.org/data/2.5/weather?q=atuona,pf&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for taolanaro, mg
# https://api.openweathermap.org/data/2.5/weather?q=taolanaro,mg&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
# Retrieving data for bathsheba, bb
# https://api.openweathermap.org/data/2.5/weather?q=bathsheba,bb&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for leh, in
# https://api.openweathermap.org/data/2.5/weather?q=leh,in&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for alofi, nu
# https://api.openweathermap.org/data/2.5/weather?q=alofi,nu&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for yellowknife, ca
# https://api.openweathermap.org/data/2.5/weather?q=yellowknife,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for cape town, za
# https://api.openweathermap.org/data/2.5/weather?q=cape town,za&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for arraial do cabo, br
# https://api.openweathermap.org/data/2.5/weather?q=arraial do cabo,br&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for miquelon, pm
# https://api.openweathermap.org/data/2.5/weather?q=miquelon,pm&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for matagami, ca
# https://api.openweathermap.org/data/2.5/weather?q=matagami,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for suceveni, ro
# https://api.openweathermap.org/data/2.5/weather?q=suceveni,ro&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for nola, cf
# https://api.openweathermap.org/data/2.5/weather?q=nola,cf&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kavieng, pg
# https://api.openweathermap.org/data/2.5/weather?q=kavieng,pg&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for upernavik, gl
# https://api.openweathermap.org/data/2.5/weather?q=upernavik,gl&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for bredasdorp, za
# https://api.openweathermap.org/data/2.5/weather?q=bredasdorp,za&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for topsham, us
# https://api.openweathermap.org/data/2.5/weather?q=topsham,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for klaksvik, fo
# https://api.openweathermap.org/data/2.5/weather?q=klaksvik,fo&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for gat, ly
# https://api.openweathermap.org/data/2.5/weather?q=gat,ly&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for karakendzha, tj
# https://api.openweathermap.org/data/2.5/weather?q=karakendzha,tj&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for marzuq, ly
# https://api.openweathermap.org/data/2.5/weather?q=marzuq,ly&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for tautira, pf
# https://api.openweathermap.org/data/2.5/weather?q=tautira,pf&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kiama, au
# https://api.openweathermap.org/data/2.5/weather?q=kiama,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for broken hill, au
# https://api.openweathermap.org/data/2.5/weather?q=broken hill,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for nordfjordeid, no
# https://api.openweathermap.org/data/2.5/weather?q=nordfjordeid,no&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for grimari, cf
# https://api.openweathermap.org/data/2.5/weather?q=grimari,cf&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for fairbanks, us
# https://api.openweathermap.org/data/2.5/weather?q=fairbanks,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for balvi, lv
# https://api.openweathermap.org/data/2.5/weather?q=balvi,lv&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for airai, pw
# https://api.openweathermap.org/data/2.5/weather?q=airai,pw&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for san quintin, mx
# https://api.openweathermap.org/data/2.5/weather?q=san quintin,mx&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for ovalle, cl
# https://api.openweathermap.org/data/2.5/weather?q=ovalle,cl&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for wanning, cn
# https://api.openweathermap.org/data/2.5/weather?q=wanning,cn&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for hermanus, za
# https://api.openweathermap.org/data/2.5/weather?q=hermanus,za&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for victoria, sc
# https://api.openweathermap.org/data/2.5/weather?q=victoria,sc&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for hervey bay, au
# https://api.openweathermap.org/data/2.5/weather?q=hervey bay,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kaeo, nz
# https://api.openweathermap.org/data/2.5/weather?q=kaeo,nz&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for pishin, pk
# https://api.openweathermap.org/data/2.5/weather?q=pishin,pk&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for ilulissat, gl
# https://api.openweathermap.org/data/2.5/weather?q=ilulissat,gl&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for busselton, au
# https://api.openweathermap.org/data/2.5/weather?q=busselton,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kuche, cn
# https://api.openweathermap.org/data/2.5/weather?q=kuche,cn&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for great yarmouth, gb
# https://api.openweathermap.org/data/2.5/weather?q=great yarmouth,gb&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for mutsamudu, km
# https://api.openweathermap.org/data/2.5/weather?q=mutsamudu,km&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for umzimvubu, za
# https://api.openweathermap.org/data/2.5/weather?q=umzimvubu,za&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for fortuna, us
# https://api.openweathermap.org/data/2.5/weather?q=fortuna,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for satitoa, ws
# https://api.openweathermap.org/data/2.5/weather?q=satitoa,ws&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for marcona, pe
# https://api.openweathermap.org/data/2.5/weather?q=marcona,pe&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for lolua, tv
# https://api.openweathermap.org/data/2.5/weather?q=lolua,tv&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for los banos, us
# https://api.openweathermap.org/data/2.5/weather?q=los banos,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for salta, ar
# https://api.openweathermap.org/data/2.5/weather?q=salta,ar&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for forestville, ca
# https://api.openweathermap.org/data/2.5/weather?q=forestville,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for lavrentiya, ru
# https://api.openweathermap.org/data/2.5/weather?q=lavrentiya,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for grindavik, is
# https://api.openweathermap.org/data/2.5/weather?q=grindavik,is&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for myanaung, mm
# https://api.openweathermap.org/data/2.5/weather?q=myanaung,mm&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for alta floresta, br
# https://api.openweathermap.org/data/2.5/weather?q=alta floresta,br&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for geraldton, au
# https://api.openweathermap.org/data/2.5/weather?q=geraldton,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for georgetown, sh
# https://api.openweathermap.org/data/2.5/weather?q=georgetown,sh&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for sao jose da coroa grande, br
# https://api.openweathermap.org/data/2.5/weather?q=sao jose da coroa grande,br&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for aurora, br
# https://api.openweathermap.org/data/2.5/weather?q=aurora,br&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for tashtyp, ru
# https://api.openweathermap.org/data/2.5/weather?q=tashtyp,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for mocuba, mz
# https://api.openweathermap.org/data/2.5/weather?q=mocuba,mz&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for nizhneyansk, ru
# https://api.openweathermap.org/data/2.5/weather?q=nizhneyansk,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for belmonte, br
# https://api.openweathermap.org/data/2.5/weather?q=belmonte,br&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for husavik, is
# https://api.openweathermap.org/data/2.5/weather?q=husavik,is&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for saint george, bm
# https://api.openweathermap.org/data/2.5/weather?q=saint george,bm&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
# Retrieving data for coihaique, cl
# https://api.openweathermap.org/data/2.5/weather?q=coihaique,cl&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for westport, ie
# https://api.openweathermap.org/data/2.5/weather?q=westport,ie&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for saskylakh, ru
# https://api.openweathermap.org/data/2.5/weather?q=saskylakh,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for mwense, zm
# https://api.openweathermap.org/data/2.5/weather?q=mwense,zm&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for baft, ir
# https://api.openweathermap.org/data/2.5/weather?q=baft,ir&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for vaitupu, wf
# https://api.openweathermap.org/data/2.5/weather?q=vaitupu,wf&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for new norfolk, au
# https://api.openweathermap.org/data/2.5/weather?q=new norfolk,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for barrow, us
# https://api.openweathermap.org/data/2.5/weather?q=barrow,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for vanimo, pg
# https://api.openweathermap.org/data/2.5/weather?q=vanimo,pg&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for port hedland, au
# https://api.openweathermap.org/data/2.5/weather?q=port hedland,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for chumikan, ru
# https://api.openweathermap.org/data/2.5/weather?q=chumikan,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for esperance, au
# https://api.openweathermap.org/data/2.5/weather?q=esperance,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for pundaguitan, ph
# https://api.openweathermap.org/data/2.5/weather?q=pundaguitan,ph&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for gushikawa, jp
# https://api.openweathermap.org/data/2.5/weather?q=gushikawa,jp&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for ukiah, us
# https://api.openweathermap.org/data/2.5/weather?q=ukiah,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for paitan, ph
# https://api.openweathermap.org/data/2.5/weather?q=paitan,ph&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for tigil, ru
# https://api.openweathermap.org/data/2.5/weather?q=tigil,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for ribeira grande, pt
# https://api.openweathermap.org/data/2.5/weather?q=ribeira grande,pt&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for lata, sb
# https://api.openweathermap.org/data/2.5/weather?q=lata,sb&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for ponta do sol, cv
# https://api.openweathermap.org/data/2.5/weather?q=ponta do sol,cv&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for mar del plata, ar
# https://api.openweathermap.org/data/2.5/weather?q=mar del plata,ar&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for sabzevar, ir
# https://api.openweathermap.org/data/2.5/weather?q=sabzevar,ir&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for hasaki, jp
# https://api.openweathermap.org/data/2.5/weather?q=hasaki,jp&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for muswellbrook, au
# https://api.openweathermap.org/data/2.5/weather?q=muswellbrook,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kerouane, gn
# https://api.openweathermap.org/data/2.5/weather?q=kerouane,gn&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for raipur, in
# https://api.openweathermap.org/data/2.5/weather?q=raipur,in&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for nome, us
# https://api.openweathermap.org/data/2.5/weather?q=nome,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for saint-philippe, re
# https://api.openweathermap.org/data/2.5/weather?q=saint-philippe,re&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for havre-saint-pierre, ca
# https://api.openweathermap.org/data/2.5/weather?q=havre-saint-pierre,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for tiksi, ru
# https://api.openweathermap.org/data/2.5/weather?q=tiksi,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for codrington, ag
# https://api.openweathermap.org/data/2.5/weather?q=codrington,ag&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for amalfi, co
# https://api.openweathermap.org/data/2.5/weather?q=amalfi,co&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for mahebourg, mu
# https://api.openweathermap.org/data/2.5/weather?q=mahebourg,mu&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for bethel, us
# https://api.openweathermap.org/data/2.5/weather?q=bethel,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for chokurdakh, ru
# https://api.openweathermap.org/data/2.5/weather?q=chokurdakh,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for karpathos, gr
# https://api.openweathermap.org/data/2.5/weather?q=karpathos,gr&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for saint-francois, gp
# https://api.openweathermap.org/data/2.5/weather?q=saint-francois,gp&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for manta, ec
# https://api.openweathermap.org/data/2.5/weather?q=manta,ec&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for yomitan, jp
# https://api.openweathermap.org/data/2.5/weather?q=yomitan,jp&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for lokosovo, ru
# https://api.openweathermap.org/data/2.5/weather?q=lokosovo,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for veraval, in
# https://api.openweathermap.org/data/2.5/weather?q=veraval,in&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for olafsvik, is
# https://api.openweathermap.org/data/2.5/weather?q=olafsvik,is&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for tezu, in
# https://api.openweathermap.org/data/2.5/weather?q=tezu,in&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for cabo san lucas, mx
# https://api.openweathermap.org/data/2.5/weather?q=cabo san lucas,mx&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for butaritari, ki
# https://api.openweathermap.org/data/2.5/weather?q=butaritari,ki&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for cidreira, br
# https://api.openweathermap.org/data/2.5/weather?q=cidreira,br&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for mollendo, pe
# https://api.openweathermap.org/data/2.5/weather?q=mollendo,pe&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for wukari, ng
# https://api.openweathermap.org/data/2.5/weather?q=wukari,ng&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for oktyabrskiy, ru
# https://api.openweathermap.org/data/2.5/weather?q=oktyabrskiy,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for acapulco, mx
# https://api.openweathermap.org/data/2.5/weather?q=acapulco,mx&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for conakry, gn
# https://api.openweathermap.org/data/2.5/weather?q=conakry,gn&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kaspiyskiy, ru
# https://api.openweathermap.org/data/2.5/weather?q=kaspiyskiy,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for bengkulu, id
# https://api.openweathermap.org/data/2.5/weather?q=bengkulu,id&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for narsaq, gl
# https://api.openweathermap.org/data/2.5/weather?q=narsaq,gl&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for tasiilaq, gl
# https://api.openweathermap.org/data/2.5/weather?q=tasiilaq,gl&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for greenville, us
# https://api.openweathermap.org/data/2.5/weather?q=greenville,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for sisimiut, gl
# https://api.openweathermap.org/data/2.5/weather?q=sisimiut,gl&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for hojai, in
# https://api.openweathermap.org/data/2.5/weather?q=hojai,in&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for tucuma, br
# https://api.openweathermap.org/data/2.5/weather?q=tucuma,br&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for rosendal, no
# https://api.openweathermap.org/data/2.5/weather?q=rosendal,no&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for manokwari, id
# https://api.openweathermap.org/data/2.5/weather?q=manokwari,id&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
# Retrieving data for ereymentau, kz
# https://api.openweathermap.org/data/2.5/weather?q=ereymentau,kz&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for sabathu, in
# https://api.openweathermap.org/data/2.5/weather?q=sabathu,in&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for port elizabeth, za
# https://api.openweathermap.org/data/2.5/weather?q=port elizabeth,za&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for chicama, pe
# https://api.openweathermap.org/data/2.5/weather?q=chicama,pe&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for yarmouth, ca
# https://api.openweathermap.org/data/2.5/weather?q=yarmouth,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for khani, ru
# https://api.openweathermap.org/data/2.5/weather?q=khani,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for henties bay, na
# https://api.openweathermap.org/data/2.5/weather?q=henties bay,na&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kalabo, zm
# https://api.openweathermap.org/data/2.5/weather?q=kalabo,zm&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for steinbach, ca
# https://api.openweathermap.org/data/2.5/weather?q=steinbach,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for qaanaaq, gl
# https://api.openweathermap.org/data/2.5/weather?q=qaanaaq,gl&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for svetlaya, ru
# https://api.openweathermap.org/data/2.5/weather?q=svetlaya,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for mudbidri, in
# https://api.openweathermap.org/data/2.5/weather?q=mudbidri,in&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for dongsheng, cn
# https://api.openweathermap.org/data/2.5/weather?q=dongsheng,cn&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for potiskum, ng
# https://api.openweathermap.org/data/2.5/weather?q=potiskum,ng&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kavaratti, in
# https://api.openweathermap.org/data/2.5/weather?q=kavaratti,in&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for katsuura, jp
# https://api.openweathermap.org/data/2.5/weather?q=katsuura,jp&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for saleaula, ws
# https://api.openweathermap.org/data/2.5/weather?q=saleaula,ws&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for san patricio, mx
# https://api.openweathermap.org/data/2.5/weather?q=san patricio,mx&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for sept-iles, ca
# https://api.openweathermap.org/data/2.5/weather?q=sept-iles,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for januaria, br
# https://api.openweathermap.org/data/2.5/weather?q=januaria,br&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for pitanga, br
# https://api.openweathermap.org/data/2.5/weather?q=pitanga,br&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kenai, us
# https://api.openweathermap.org/data/2.5/weather?q=kenai,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for cayenne, gf
# https://api.openweathermap.org/data/2.5/weather?q=cayenne,gf&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for bundaberg, au
# https://api.openweathermap.org/data/2.5/weather?q=bundaberg,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for muros, es
# https://api.openweathermap.org/data/2.5/weather?q=muros,es&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for salalah, om
# https://api.openweathermap.org/data/2.5/weather?q=salalah,om&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for camacha, pt
# https://api.openweathermap.org/data/2.5/weather?q=camacha,pt&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for jega, ng
# https://api.openweathermap.org/data/2.5/weather?q=jega,ng&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for nishihara, jp
# https://api.openweathermap.org/data/2.5/weather?q=nishihara,jp&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for el sauzal, mx
# https://api.openweathermap.org/data/2.5/weather?q=el sauzal,mx&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for darab, ir
# https://api.openweathermap.org/data/2.5/weather?q=darab,ir&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for marawi, sd
# https://api.openweathermap.org/data/2.5/weather?q=marawi,sd&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for ahipara, nz
# https://api.openweathermap.org/data/2.5/weather?q=ahipara,nz&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for vardo, no
# https://api.openweathermap.org/data/2.5/weather?q=vardo,no&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for agadez, ne
# https://api.openweathermap.org/data/2.5/weather?q=agadez,ne&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for pasighat, in
# https://api.openweathermap.org/data/2.5/weather?q=pasighat,in&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for bacolod, ph
# https://api.openweathermap.org/data/2.5/weather?q=bacolod,ph&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for abha, sa
# https://api.openweathermap.org/data/2.5/weather?q=abha,sa&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for provideniya, ru
# https://api.openweathermap.org/data/2.5/weather?q=provideniya,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for attawapiskat, ca
# https://api.openweathermap.org/data/2.5/weather?q=attawapiskat,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for gizo, sb
# https://api.openweathermap.org/data/2.5/weather?q=gizo,sb&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for bandarbeyla, so
# https://api.openweathermap.org/data/2.5/weather?q=bandarbeyla,so&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for hazleton, us
# https://api.openweathermap.org/data/2.5/weather?q=hazleton,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for puerto carreno, co
# https://api.openweathermap.org/data/2.5/weather?q=puerto carreno,co&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for auki, sb
# https://api.openweathermap.org/data/2.5/weather?q=auki,sb&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for torbay, ca
# https://api.openweathermap.org/data/2.5/weather?q=torbay,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for khatanga, ru
# https://api.openweathermap.org/data/2.5/weather?q=khatanga,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for alice springs, au
# https://api.openweathermap.org/data/2.5/weather?q=alice springs,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kankakee, us
# https://api.openweathermap.org/data/2.5/weather?q=kankakee,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for porto novo, cv
# https://api.openweathermap.org/data/2.5/weather?q=porto novo,cv&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for aksarka, ru
# https://api.openweathermap.org/data/2.5/weather?q=aksarka,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for pidhorodna, ua
# https://api.openweathermap.org/data/2.5/weather?q=pidhorodna,ua&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for luganville, vu
# https://api.openweathermap.org/data/2.5/weather?q=luganville,vu&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kapaa, us
# https://api.openweathermap.org/data/2.5/weather?q=kapaa,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for zhanaozen, kz
# https://api.openweathermap.org/data/2.5/weather?q=zhanaozen,kz&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for deh rawud, af
# https://api.openweathermap.org/data/2.5/weather?q=deh rawud,af&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for labuhan, id
# https://api.openweathermap.org/data/2.5/weather?q=labuhan,id&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for shaunavon, ca
# https://api.openweathermap.org/data/2.5/weather?q=shaunavon,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for saldanha, za
# https://api.openweathermap.org/data/2.5/weather?q=saldanha,za&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for pisco, pe
# https://api.openweathermap.org/data/2.5/weather?q=pisco,pe&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for banjar, id
# https://api.openweathermap.org/data/2.5/weather?q=banjar,id&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
# Retrieving data for mildmay, ca
# https://api.openweathermap.org/data/2.5/weather?q=mildmay,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for dzhebariki-khaya, ru
# https://api.openweathermap.org/data/2.5/weather?q=dzhebariki-khaya,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for neryungri, ru
# https://api.openweathermap.org/data/2.5/weather?q=neryungri,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for sobolevo, ru
# https://api.openweathermap.org/data/2.5/weather?q=sobolevo,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for antalaha, mg
# https://api.openweathermap.org/data/2.5/weather?q=antalaha,mg&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for solone, ua
# https://api.openweathermap.org/data/2.5/weather?q=solone,ua&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for el wasta, eg
# https://api.openweathermap.org/data/2.5/weather?q=el wasta,eg&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for oktyabrskoye, ru
# https://api.openweathermap.org/data/2.5/weather?q=oktyabrskoye,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kutum, sd
# https://api.openweathermap.org/data/2.5/weather?q=kutum,sd&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for distraccion, co
# https://api.openweathermap.org/data/2.5/weather?q=distraccion,co&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for inuvik, ca
# https://api.openweathermap.org/data/2.5/weather?q=inuvik,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for arona, es
# https://api.openweathermap.org/data/2.5/weather?q=arona,es&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for songling, cn
# https://api.openweathermap.org/data/2.5/weather?q=songling,cn&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for yekaterinoslavka, ru
# https://api.openweathermap.org/data/2.5/weather?q=yekaterinoslavka,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for fort pierce, us
# https://api.openweathermap.org/data/2.5/weather?q=fort pierce,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for lerwick, gb
# https://api.openweathermap.org/data/2.5/weather?q=lerwick,gb&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for avarua, ck
# https://api.openweathermap.org/data/2.5/weather?q=avarua,ck&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for zonguldak, tr
# https://api.openweathermap.org/data/2.5/weather?q=zonguldak,tr&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for moyale, ke
# https://api.openweathermap.org/data/2.5/weather?q=moyale,ke&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for pendleton, us
# https://api.openweathermap.org/data/2.5/weather?q=pendleton,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for pevek, ru
# https://api.openweathermap.org/data/2.5/weather?q=pevek,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for palabuhanratu, id
# https://api.openweathermap.org/data/2.5/weather?q=palabuhanratu,id&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for mayumba, ga
# https://api.openweathermap.org/data/2.5/weather?q=mayumba,ga&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for lieksa, fi
# https://api.openweathermap.org/data/2.5/weather?q=lieksa,fi&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for palanga, lt
# https://api.openweathermap.org/data/2.5/weather?q=palanga,lt&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for saiha, in
# https://api.openweathermap.org/data/2.5/weather?q=saiha,in&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for bambous virieux, mu
# https://api.openweathermap.org/data/2.5/weather?q=bambous virieux,mu&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for taoudenni, ml
# https://api.openweathermap.org/data/2.5/weather?q=taoudenni,ml&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for high rock, bs
# https://api.openweathermap.org/data/2.5/weather?q=high rock,bs&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for faanui, pf
# https://api.openweathermap.org/data/2.5/weather?q=faanui,pf&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for norman wells, ca
# https://api.openweathermap.org/data/2.5/weather?q=norman wells,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for maloy, no
# https://api.openweathermap.org/data/2.5/weather?q=maloy,no&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for luderitz, na
# https://api.openweathermap.org/data/2.5/weather?q=luderitz,na&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for boa vista, br
# https://api.openweathermap.org/data/2.5/weather?q=boa vista,br&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for arroyo, us
# https://api.openweathermap.org/data/2.5/weather?q=arroyo,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for waitati, nz
# https://api.openweathermap.org/data/2.5/weather?q=waitati,nz&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for brigantine, us
# https://api.openweathermap.org/data/2.5/weather?q=brigantine,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for sambava, mg
# https://api.openweathermap.org/data/2.5/weather?q=sambava,mg&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for hay river, ca
# https://api.openweathermap.org/data/2.5/weather?q=hay river,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for dawei, mm
# https://api.openweathermap.org/data/2.5/weather?q=dawei,mm&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for rudnogorsk, ru
# https://api.openweathermap.org/data/2.5/weather?q=rudnogorsk,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for amderma, ru
# https://api.openweathermap.org/data/2.5/weather?q=amderma,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for pangnirtung, ca
# https://api.openweathermap.org/data/2.5/weather?q=pangnirtung,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for rawson, ar
# https://api.openweathermap.org/data/2.5/weather?q=rawson,ar&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for plastun, ru
# https://api.openweathermap.org/data/2.5/weather?q=plastun,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for harnai, pk
# https://api.openweathermap.org/data/2.5/weather?q=harnai,pk&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for sigli, id
# https://api.openweathermap.org/data/2.5/weather?q=sigli,id&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for jacala, mx
# https://api.openweathermap.org/data/2.5/weather?q=jacala,mx&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kruisfontein, za
# https://api.openweathermap.org/data/2.5/weather?q=kruisfontein,za&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for sao filipe, cv
# https://api.openweathermap.org/data/2.5/weather?q=sao filipe,cv&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for barentsburg, sj
# https://api.openweathermap.org/data/2.5/weather?q=barentsburg,sj&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for tahoua, ne
# https://api.openweathermap.org/data/2.5/weather?q=tahoua,ne&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for banepa, np
# https://api.openweathermap.org/data/2.5/weather?q=banepa,np&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for nelson bay, au
# https://api.openweathermap.org/data/2.5/weather?q=nelson bay,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for marsa matruh, eg
# https://api.openweathermap.org/data/2.5/weather?q=marsa matruh,eg&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for merauke, id
# https://api.openweathermap.org/data/2.5/weather?q=merauke,id&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for isangel, vu
# https://api.openweathermap.org/data/2.5/weather?q=isangel,vu&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for qaqortoq, gl
# https://api.openweathermap.org/data/2.5/weather?q=qaqortoq,gl&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for chokwe, mz
# https://api.openweathermap.org/data/2.5/weather?q=chokwe,mz&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for port-gentil, ga
# https://api.openweathermap.org/data/2.5/weather?q=port-gentil,ga&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for pangai, to
# https://api.openweathermap.org/data/2.5/weather?q=pangai,to&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
# Retrieving data for afikpo, ng
# https://api.openweathermap.org/data/2.5/weather?q=afikpo,ng&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kieta, pg
# https://api.openweathermap.org/data/2.5/weather?q=kieta,pg&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for rio grande, br
# https://api.openweathermap.org/data/2.5/weather?q=rio grande,br&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for morro da fumaca, br
# https://api.openweathermap.org/data/2.5/weather?q=morro da fumaca,br&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for lasa, cn
# https://api.openweathermap.org/data/2.5/weather?q=lasa,cn&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kaitangata, nz
# https://api.openweathermap.org/data/2.5/weather?q=kaitangata,nz&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for itarema, br
# https://api.openweathermap.org/data/2.5/weather?q=itarema,br&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for bereda, so
# https://api.openweathermap.org/data/2.5/weather?q=bereda,so&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for davila, ph
# https://api.openweathermap.org/data/2.5/weather?q=davila,ph&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for puerto ayora, ec
# https://api.openweathermap.org/data/2.5/weather?q=puerto ayora,ec&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for bilibino, ru
# https://api.openweathermap.org/data/2.5/weather?q=bilibino,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for port lincoln, au
# https://api.openweathermap.org/data/2.5/weather?q=port lincoln,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for peniche, pt
# https://api.openweathermap.org/data/2.5/weather?q=peniche,pt&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for paharpur, pk
# https://api.openweathermap.org/data/2.5/weather?q=paharpur,pk&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for ketchikan, us
# https://api.openweathermap.org/data/2.5/weather?q=ketchikan,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kerman, ir
# https://api.openweathermap.org/data/2.5/weather?q=kerman,ir&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for bayan, kw
# https://api.openweathermap.org/data/2.5/weather?q=bayan,kw&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for souillac, mu
# https://api.openweathermap.org/data/2.5/weather?q=souillac,mu&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for grand centre, ca
# https://api.openweathermap.org/data/2.5/weather?q=grand centre,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for mago, ru
# https://api.openweathermap.org/data/2.5/weather?q=mago,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for port macquarie, au
# https://api.openweathermap.org/data/2.5/weather?q=port macquarie,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for miles city, us
# https://api.openweathermap.org/data/2.5/weather?q=miles city,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for shenjiamen, cn
# https://api.openweathermap.org/data/2.5/weather?q=shenjiamen,cn&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for dingle, ie
# https://api.openweathermap.org/data/2.5/weather?q=dingle,ie&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for grand gaube, mu
# https://api.openweathermap.org/data/2.5/weather?q=grand gaube,mu&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for port augusta, au
# https://api.openweathermap.org/data/2.5/weather?q=port augusta,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for la union, cl
# https://api.openweathermap.org/data/2.5/weather?q=la union,cl&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for quatre cocos, mu
# https://api.openweathermap.org/data/2.5/weather?q=quatre cocos,mu&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for lagoa, pt
# https://api.openweathermap.org/data/2.5/weather?q=lagoa,pt&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for san joaquin, bo
# https://api.openweathermap.org/data/2.5/weather?q=san joaquin,bo&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for harpanahalli, in
# https://api.openweathermap.org/data/2.5/weather?q=harpanahalli,in&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for constitucion, mx
# https://api.openweathermap.org/data/2.5/weather?q=constitucion,mx&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for ishigaki, jp
# https://api.openweathermap.org/data/2.5/weather?q=ishigaki,jp&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for suez, eg
# https://api.openweathermap.org/data/2.5/weather?q=suez,eg&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for mandalgovi, mn
# https://api.openweathermap.org/data/2.5/weather?q=mandalgovi,mn&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for batavia, us
# https://api.openweathermap.org/data/2.5/weather?q=batavia,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for livingston, us
# https://api.openweathermap.org/data/2.5/weather?q=livingston,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for san cristobal, ec
# https://api.openweathermap.org/data/2.5/weather?q=san cristobal,ec&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for severo-kurilsk, ru
# https://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for karlskrona, se
# https://api.openweathermap.org/data/2.5/weather?q=karlskrona,se&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for bose, cn
# https://api.openweathermap.org/data/2.5/weather?q=bose,cn&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for portland, au
# https://api.openweathermap.org/data/2.5/weather?q=portland,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for lebedinyy, ru
# https://api.openweathermap.org/data/2.5/weather?q=lebedinyy,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for coahuayana, mx
# https://api.openweathermap.org/data/2.5/weather?q=coahuayana,mx&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for balkhash, kz
# https://api.openweathermap.org/data/2.5/weather?q=balkhash,kz&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for atar, mr
# https://api.openweathermap.org/data/2.5/weather?q=atar,mr&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for athabasca, ca
# https://api.openweathermap.org/data/2.5/weather?q=athabasca,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kondratovo, ru
# https://api.openweathermap.org/data/2.5/weather?q=kondratovo,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for moussoro, td
# ...
#
# Retrieving data for sitka, us
# https://api.openweathermap.org/data/2.5/weather?q=sitka,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for buta, cd
# https://api.openweathermap.org/data/2.5/weather?q=buta,cd&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for parana, ar
# https://api.openweathermap.org/data/2.5/weather?q=parana,ar&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for beringovskiy, ru
# https://api.openweathermap.org/data/2.5/weather?q=beringovskiy,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for komsomolskiy, ru
# https://api.openweathermap.org/data/2.5/weather?q=komsomolskiy,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for liniere, ca
# https://api.openweathermap.org/data/2.5/weather?q=liniere,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kapoeta, sd
# https://api.openweathermap.org/data/2.5/weather?q=kapoeta,sd&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for beitbridge, zw
# https://api.openweathermap.org/data/2.5/weather?q=beitbridge,zw&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for jesup, us
# https://api.openweathermap.org/data/2.5/weather?q=jesup,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for ponta delgada, pt
# https://api.openweathermap.org/data/2.5/weather?q=ponta delgada,pt&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for nurota, uz
# https://api.openweathermap.org/data/2.5/weather?q=nurota,uz&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for dianopolis, br
# https://api.openweathermap.org/data/2.5/weather?q=dianopolis,br&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for boyle, ie
# https://api.openweathermap.org/data/2.5/weather?q=boyle,ie&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for klyuchi, ru
# https://api.openweathermap.org/data/2.5/weather?q=klyuchi,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for nova olimpia, br
# https://api.openweathermap.org/data/2.5/weather?q=nova olimpia,br&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for longyearbyen, sj
# https://api.openweathermap.org/data/2.5/weather?q=longyearbyen,sj&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for bongandanga, cd
# https://api.openweathermap.org/data/2.5/weather?q=bongandanga,cd&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for mtwara, tz
# https://api.openweathermap.org/data/2.5/weather?q=mtwara,tz&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for lubango, ao
# https://api.openweathermap.org/data/2.5/weather?q=lubango,ao&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for rajo khanani, pk
# https://api.openweathermap.org/data/2.5/weather?q=rajo khanani,pk&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for khandagayty, ru
# https://api.openweathermap.org/data/2.5/weather?q=khandagayty,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for novyy urengoy, ru
# https://api.openweathermap.org/data/2.5/weather?q=novyy urengoy,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for svetlogorsk, ru
# https://api.openweathermap.org/data/2.5/weather?q=svetlogorsk,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for honiara, sb
# https://api.openweathermap.org/data/2.5/weather?q=honiara,sb&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for casa grande, us
# https://api.openweathermap.org/data/2.5/weather?q=casa grande,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for sorland, no
# https://api.openweathermap.org/data/2.5/weather?q=sorland,no&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for ratnagiri, in
# https://api.openweathermap.org/data/2.5/weather?q=ratnagiri,in&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for sydney, au
# https://api.openweathermap.org/data/2.5/weather?q=sydney,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for nanakuli, us
# https://api.openweathermap.org/data/2.5/weather?q=nanakuli,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for lakatoro, vu
# https://api.openweathermap.org/data/2.5/weather?q=lakatoro,vu&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for bonthe, sl
# https://api.openweathermap.org/data/2.5/weather?q=bonthe,sl&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for galveston, us
# https://api.openweathermap.org/data/2.5/weather?q=galveston,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for lompoc, us
# https://api.openweathermap.org/data/2.5/weather?q=lompoc,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for nantucket, us
# https://api.openweathermap.org/data/2.5/weather?q=nantucket,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
# Retrieving data for sovetskiy, ru
# https://api.openweathermap.org/data/2.5/weather?q=sovetskiy,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for haines junction, ca
# https://api.openweathermap.org/data/2.5/weather?q=haines junction,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for comodoro rivadavia, ar
# https://api.openweathermap.org/data/2.5/weather?q=comodoro rivadavia,ar&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for bairiki, ki
# https://api.openweathermap.org/data/2.5/weather?q=bairiki,ki&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kasane, bw
# https://api.openweathermap.org/data/2.5/weather?q=kasane,bw&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for sao joao da barra, br
# https://api.openweathermap.org/data/2.5/weather?q=sao joao da barra,br&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for vestmanna, fo
# https://api.openweathermap.org/data/2.5/weather?q=vestmanna,fo&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kilindoni, tz
# https://api.openweathermap.org/data/2.5/weather?q=kilindoni,tz&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for formoso do araguaia, br
# https://api.openweathermap.org/data/2.5/weather?q=formoso do araguaia,br&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for katha, mm
# https://api.openweathermap.org/data/2.5/weather?q=katha,mm&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for bartica, gy
# https://api.openweathermap.org/data/2.5/weather?q=bartica,gy&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for lewiston, us
# https://api.openweathermap.org/data/2.5/weather?q=lewiston,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for mariental, na
# https://api.openweathermap.org/data/2.5/weather?q=mariental,na&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for turangi, nz
# https://api.openweathermap.org/data/2.5/weather?q=turangi,nz&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kachikau, bw
# https://api.openweathermap.org/data/2.5/weather?q=kachikau,bw&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for vila velha, br
# https://api.openweathermap.org/data/2.5/weather?q=vila velha,br&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for nizhniy kuranakh, ru
# https://api.openweathermap.org/data/2.5/weather?q=nizhniy kuranakh,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for yumen, cn
# https://api.openweathermap.org/data/2.5/weather?q=yumen,cn&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for sola, vu
# https://api.openweathermap.org/data/2.5/weather?q=sola,vu&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for laguna, br
# https://api.openweathermap.org/data/2.5/weather?q=laguna,br&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for sao gabriel da cachoeira, br
# https://api.openweathermap.org/data/2.5/weather?q=sao gabriel da cachoeira,br&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for nanortalik, gl
# https://api.openweathermap.org/data/2.5/weather?q=nanortalik,gl&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for ceuta, es
# https://api.openweathermap.org/data/2.5/weather?q=ceuta,es&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kandi, in
# https://api.openweathermap.org/data/2.5/weather?q=kandi,in&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for isiro, cd
# https://api.openweathermap.org/data/2.5/weather?q=isiro,cd&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for soyo, ao
# https://api.openweathermap.org/data/2.5/weather?q=soyo,ao&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for north bend, us
# https://api.openweathermap.org/data/2.5/weather?q=north bend,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for mecca, sa
# https://api.openweathermap.org/data/2.5/weather?q=mecca,sa&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for karangampel, id
# https://api.openweathermap.org/data/2.5/weather?q=karangampel,id&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for monywa, mm
# https://api.openweathermap.org/data/2.5/weather?q=monywa,mm&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for suoyarvi, ru
# https://api.openweathermap.org/data/2.5/weather?q=suoyarvi,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for herat, af
# https://api.openweathermap.org/data/2.5/weather?q=herat,af&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for warqla, dz
# https://api.openweathermap.org/data/2.5/weather?q=warqla,dz&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for hobyo, so
# https://api.openweathermap.org/data/2.5/weather?q=hobyo,so&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for naze, jp
# https://api.openweathermap.org/data/2.5/weather?q=naze,jp&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for betioky, mg
# https://api.openweathermap.org/data/2.5/weather?q=betioky,mg&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for vestmannaeyjar, is
# https://api.openweathermap.org/data/2.5/weather?q=vestmannaeyjar,is&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for saint-paul, re
# https://api.openweathermap.org/data/2.5/weather?q=saint-paul,re&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for kondinskoye, ru
# https://api.openweathermap.org/data/2.5/weather?q=kondinskoye,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for akhtanizovskaya, ru
# https://api.openweathermap.org/data/2.5/weather?q=akhtanizovskaya,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for teguldet, ru
# https://api.openweathermap.org/data/2.5/weather?q=teguldet,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for krasnoselkup, ru
# https://api.openweathermap.org/data/2.5/weather?q=krasnoselkup,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for mercedes, uy
# https://api.openweathermap.org/data/2.5/weather?q=mercedes,uy&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for agua dulce, mx
# https://api.openweathermap.org/data/2.5/weather?q=agua dulce,mx&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for komarikhinskiy, ru
# https://api.openweathermap.org/data/2.5/weather?q=komarikhinskiy,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for bayanday, ru
# https://api.openweathermap.org/data/2.5/weather?q=bayanday,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for mingyue, cn
# https://api.openweathermap.org/data/2.5/weather?q=mingyue,cn&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for moctezuma, mx
# https://api.openweathermap.org/data/2.5/weather?q=moctezuma,mx&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for lakes entrance, au
# https://api.openweathermap.org/data/2.5/weather?q=lakes entrance,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for riwaka, nz
# https://api.openweathermap.org/data/2.5/weather?q=riwaka,nz&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for derzhavinsk, kz
# https://api.openweathermap.org/data/2.5/weather?q=derzhavinsk,kz&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for lensk, ru
# https://api.openweathermap.org/data/2.5/weather?q=lensk,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for fastiv, ua
# https://api.openweathermap.org/data/2.5/weather?q=fastiv,ua&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for groton, us
# https://api.openweathermap.org/data/2.5/weather?q=groton,us&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for alekseyevsk, ru
# https://api.openweathermap.org/data/2.5/weather?q=alekseyevsk,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for roald, no
# https://api.openweathermap.org/data/2.5/weather?q=roald,no&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for aklavik, ca
# https://api.openweathermap.org/data/2.5/weather?q=aklavik,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for ijaki, ki
# https://api.openweathermap.org/data/2.5/weather?q=ijaki,ki&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for polovinnoye, ru
# https://api.openweathermap.org/data/2.5/weather?q=polovinnoye,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for rudbar, ir
# https://api.openweathermap.org/data/2.5/weather?q=rudbar,ir&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
# Retrieving data for diplo, pk
# https://api.openweathermap.org/data/2.5/weather?q=diplo,pk&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for takoradi, gh
# https://api.openweathermap.org/data/2.5/weather?q=takoradi,gh&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for dicabisagan, ph
# https://api.openweathermap.org/data/2.5/weather?q=dicabisagan,ph&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for zhaotong, cn
# https://api.openweathermap.org/data/2.5/weather?q=zhaotong,cn&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for huejuquilla el alto, mx
# https://api.openweathermap.org/data/2.5/weather?q=huejuquilla el alto,mx&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for spornoye, ru
# https://api.openweathermap.org/data/2.5/weather?q=spornoye,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for orcopampa, pe
# https://api.openweathermap.org/data/2.5/weather?q=orcopampa,pe&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for priiskovyy, ru
# https://api.openweathermap.org/data/2.5/weather?q=priiskovyy,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for faya, td
# https://api.openweathermap.org/data/2.5/weather?q=faya,td&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for malbork, pl
# https://api.openweathermap.org/data/2.5/weather?q=malbork,pl&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for lang son, vn
# https://api.openweathermap.org/data/2.5/weather?q=lang son,vn&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for usinsk, ru
# https://api.openweathermap.org/data/2.5/weather?q=usinsk,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for pimentel, pe
# https://api.openweathermap.org/data/2.5/weather?q=pimentel,pe&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for bhinga, in
# https://api.openweathermap.org/data/2.5/weather?q=bhinga,in&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for batemans bay, au
# https://api.openweathermap.org/data/2.5/weather?q=batemans bay,au&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for dalbandin, pk
# https://api.openweathermap.org/data/2.5/weather?q=dalbandin,pk&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for ha noi, vn
# https://api.openweathermap.org/data/2.5/weather?q=ha noi,vn&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for hualmay, pe
# https://api.openweathermap.org/data/2.5/weather?q=hualmay,pe&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for ocho rios, jm
# https://api.openweathermap.org/data/2.5/weather?q=ocho rios,jm&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for montale, it
# https://api.openweathermap.org/data/2.5/weather?q=montale,it&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for bogandinskiy, ru
# https://api.openweathermap.org/data/2.5/weather?q=bogandinskiy,ru&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for itoman, jp
# https://api.openweathermap.org/data/2.5/weather?q=itoman,jp&APPID=bd71d257a3c62f55b2e64e0dddf15ed1
#
# Retrieving data for bonnyville, ca
# https://api.openweathermap.org/data/2.5/weather?q=bonnyville,ca&APPID=bd71d257a3c62f55b2e64e0dddf15ed1

# %%
len(citieslat)
# Out:
# 552

# %%
import pandas as pd
cities_df = pd.DataFrame({"City ID":cityidlist,"City Name":citiesname,"Country Code":countrycode,
                          "Latitude":citieslat,"Longitude":citieslng,"Temperature":templist,"Humidity":humlist,
                          "Cloudiness":cloudiness,"Wind Speed":windspeedlist})



cities_df = cities_df[["City ID","City Name","Country Code","Latitude","Longitude","Temperature",
                      "Humidity","Cloudiness","Wind Speed"]]
cities_df.head()
# Out:
#    City ID     City Name Country Code  Latitude  Longitude  Temperature  \
# 0  6170031   tuktoyaktuk           ca     69.44    -133.03      271.150
# 1  3874787  punta arenas           cl    -53.16     -70.91      274.150
# 2  2074865     carnarvon           au    -24.87     113.63      292.475
# 3  3833367       ushuaia           ar    -54.81     -68.31      266.925
# 4   780687      berlevag           no     70.86      29.09      277.525
#
#    Humidity  Cloudiness  Wind Speed
# 0        94          68        4.10
# 1       100          90        1.50
# 2       100           0        1.12
# 3       100           0        1.17
# 4        94          80        3.22

# %%
import matplotlib.pyplot as plt
x_axis = cities_df["Latitude"]
y_axis = cities_df["Temperature"]
plt.grid(True)    
plt.title("City Latitude vs Max Temperature (06/08/18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.xlim(-80,100)
plt.ylim(240,320)
plt.scatter(x_axis,y_axis,  marker="o", color="blue")

plt.show()

# %%
x_axis = cities_df["Latitude"]
y_axis = cities_df["Humidity"]
plt.grid(True)    
plt.title("City Latitude vs Humidity (06/08/18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.xlim(-80,100)
plt.ylim(-20,120)
plt.scatter(x_axis,y_axis,  marker="o", color="blue")

plt.show()

# %%
x_axis = cities_df["Latitude"]
y_axis = cities_df["Cloudiness"]
plt.grid(True)    
plt.title("City Latitude vs Cloudiness (06/08/18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.xlim(-80,100)
plt.ylim(-20,120)
plt.scatter(x_axis,y_axis,  marker="o", color="blue")

plt.show()

# %%
x_axis = cities_df["Latitude"]
y_axis = cities_df["Wind Speed"]
plt.grid(True)    
plt.title("City Latitude vs Wind Speed (06/08/18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.xlim(-80,100)
plt.ylim(-5,20)
plt.scatter(x_axis,y_axis,  marker="o", color="blue")

plt.show()

# %%
img = plt.imread("wm1.gif")
fig, ax = plt.subplots()
ax.imshow(img, extent=[-180,180, -90,90])

x_axis = cities_df["Longitude"]
y_axis = cities_df["Latitude"]
plt.title("City Latitude vs Wind Speed (06/08/18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.xlim(-180,180)
plt.ylim(-90,90)
plt.scatter(x_axis,y_axis,  marker="o", color="blue")

plt.show()
