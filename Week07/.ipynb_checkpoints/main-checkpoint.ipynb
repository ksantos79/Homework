# %%
import tweepy
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from config import consumer_key,consumer_secret ,access_token,access_token_secret

# %%
consumer_key = consumer_key
consumer_secret = consumer_secret
access_token = access_token
access_token_secret = access_token_secret

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

text_tweet = []
date_tweet = []
compound_list = []
positive_list = []
neutral_list = []
negative_list = []
tweets_ago = []
counter = 1
analyzer = SentimentIntensityAnalyzer()

target_account = "@BBCNews"
for x in range(1, 6):
    tweets = api.user_timeline(target_account, page=x)
    for tweet in tweets:

        text_tweet.append(tweet["text"])
        date_tweet.append(tweet["created_at"])
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]

        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)
        
        tweets_ago.append(counter)
        counter += 1

# %%
bbc_df = pd.DataFrame({"Twitter Account":"@BBCNews",
                       "Tweet Date":date_tweet,
                       "Tweet":text_tweet,
                       "Compound":compound_list,
                       "Positive":positive_list,
                       "Neutral":neutral_list,
                       "Negative":negative_list,
                       "Tweets Ago":tweets_ago
                      })
bbc_df=bbc_df[["Twitter Account","Tweet Date","Tweet","Compound","Positive","Neutral","Negative","Tweets Ago"]]
bbc_df.to_csv("bbc.csv", sep=',', encoding='utf-8')
bbc_df.head()
# Out:
#   Twitter Account                      Tweet Date  \
# 0        @BBCNews  Sat Jun 23 17:01:03 +0000 2018
# 1        @BBCNews  Sat Jun 23 16:58:30 +0000 2018
# 2        @BBCNews  Sat Jun 23 16:00:29 +0000 2018
# 3        @BBCNews  Sat Jun 23 15:07:56 +0000 2018
# 4        @BBCNews  Sat Jun 23 14:58:32 +0000 2018
#
#                                                Tweet  Compound  Positive  \
# 0  Among the blue flags: Views from the pro-EU ma...    0.0000     0.000
# 1  Greater Manchester Police 'knew boy was with p...    0.3612     0.238
# 2  Italy migrant row: Malta defiant over stranded...    0.3400     0.250
# 3  Lost cat reunited with owner after 10 years ht...   -0.3182     0.000
# 4  England women lose to South Africa by six wick...   -0.3182     0.093
#
#    Neutral  Negative  Tweets Ago
# 0    1.000     0.000           1
# 1    0.762     0.000           2
# 2    0.606     0.144           3
# 3    0.777     0.223           4
# 4    0.728     0.179           5

# %%
x_vals = bbc_df["Tweets Ago"]
y_vals = bbc_df["Compound"]
plt.plot(x_vals*-1,
         y_vals, marker="o", linewidth=0.25,
         alpha=0.8)


analysis_date = datetime.now()
analysis_date = analysis_date.strftime("%Y-%m-%d")
plt.title(f"Sentiment Analysis of Tweets ({analysis_date}) for @BBC")
plt.xlim(-100,0) 
plt.ylim(-1,1) 
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.grid()
plt.savefig("bbc.png")
plt.show()

# %%
text_tweet = []
date_tweet = []
compound_list = []
positive_list = []
neutral_list = []
negative_list = []
tweets_ago = []
counter = 1
analyzer = SentimentIntensityAnalyzer()

target_account = "@CBSNews"
for x in range(1, 6):
    tweets = api.user_timeline(target_account, page=x)
    for tweet in tweets:

        text_tweet.append(tweet["text"])
        date_tweet.append(tweet["created_at"])
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]

        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)
        
        tweets_ago.append(counter)
        counter += 1

# %%
cbs_df = pd.DataFrame({"Twitter Account":"@CBSNews",
                       "Tweet Date":date_tweet,
                       "Tweet":text_tweet,
                       "Compound":compound_list,
                       "Positive":positive_list,
                       "Neutral":neutral_list,
                       "Negative":negative_list,
                       "Tweets Ago":tweets_ago
                      })
cbs_df=cbs_df[["Twitter Account","Tweet Date","Tweet","Compound","Positive","Neutral","Negative","Tweets Ago"]]
cbs_df.to_csv("cbs.csv", sep=',', encoding='utf-8')
cbs_df.head()
# Out:
#   Twitter Account                      Tweet Date  \
# 0        @CBSNews  Sat Jun 23 16:50:23 +0000 2018
# 1        @CBSNews  Sat Jun 23 16:40:06 +0000 2018
# 2        @CBSNews  Sat Jun 23 16:32:16 +0000 2018
# 3        @CBSNews  Sat Jun 23 16:19:36 +0000 2018
# 4        @CBSNews  Sat Jun 23 16:00:38 +0000 2018
#
#                                                Tweet  Compound  Positive  \
# 0  BARREL ROLL: It's unclear whether any of the b...    0.2382     0.141
# 1  2018 World Cup: Schedule, scores and updates f...    0.0000     0.000
# 2  RT @48hours: After he was brought into custody...    0.3612     0.137
# 3  An explosion rocked a stadium where Zimbabwe's...    0.0000     0.000
# 4  Sarah Sanders says a restaurant owner in Virgi...   -0.0516     0.000
#
#    Neutral  Negative  Tweets Ago
# 0    0.716     0.143           1
# 1    1.000     0.000           2
# 2    0.863     0.000           3
# 3    1.000     0.000           4
# 4    0.934     0.066           5

# %%
x_vals = cbs_df["Tweets Ago"]
y_vals = cbs_df["Compound"]
plt.plot(x_vals*-1,
         y_vals, marker="o", linewidth=0.25,
         alpha=0.8)


analysis_date = datetime.now()
analysis_date = analysis_date.strftime("%Y-%m-%d")
plt.title(f"Sentiment Analysis of Tweets ({analysis_date}) for @CBS")
plt.xlim(-100,0) 
plt.ylim(-1,1) 
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.grid()
plt.savefig("cbs.png")
plt.show()

# %%
text_tweet = []
date_tweet = []
compound_list = []
positive_list = []
neutral_list = []
negative_list = []
tweets_ago = []
counter = 1
analyzer = SentimentIntensityAnalyzer()

target_account = "@CNN"
for x in range(1, 6):
    tweets = api.user_timeline(target_account, page=x)
    for tweet in tweets:

        text_tweet.append(tweet["text"])
        date_tweet.append(tweet["created_at"])
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]

        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)
        
        tweets_ago.append(counter)
        counter += 1

# %%
cnn_df = pd.DataFrame({"Twitter Account":"@CNN",
                       "Tweet Date":date_tweet,
                       "Tweet":text_tweet,
                       "Compound":compound_list,
                       "Positive":positive_list,
                       "Neutral":neutral_list,
                       "Negative":negative_list,
                       "Tweets Ago":tweets_ago
                      })
cnn_df=cnn_df[["Twitter Account","Tweet Date","Tweet","Compound","Positive","Neutral","Negative","Tweets Ago"]]
cnn_df.to_csv("cnn.csv", sep=',', encoding='utf-8')
cnn_df.head()
# Out:
#   Twitter Account                      Tweet Date  \
# 0            @CNN  Sat Jun 23 17:05:06 +0000 2018
# 1            @CNN  Sat Jun 23 17:01:02 +0000 2018
# 2            @CNN  Sat Jun 23 16:45:13 +0000 2018
# 3            @CNN  Sat Jun 23 16:35:06 +0000 2018
# 4            @CNN  Sat Jun 23 16:24:03 +0000 2018
#
#                                                Tweet  Compound  Positive  \
# 0  The Toyota Century, a car of choice for Japan'...    0.0000       0.0
# 1  Jane Clementi, whose 18-year-old son, Tyler Cl...   -0.9217       0.0
# 2  A 9-year-old boy in Greece permanently injured...   -0.4019       0.0
# 3  New Zealand Prime Minister Jacinda Ardern beca...    0.0000       0.0
# 4  President Trump claims crime in Germany "is wa...   -0.5423       0.0
#
#    Neutral  Negative  Tweets Ago
# 0    1.000     0.000           1
# 1    0.516     0.484           2
# 2    0.870     0.130           3
# 3    1.000     0.000           4
# 4    0.851     0.149           5

# %%
x_vals = cnn_df["Tweets Ago"]
y_vals = cnn_df["Compound"]
plt.plot(x_vals*-1,
         y_vals, marker="o", linewidth=0.25,
         alpha=0.8)


analysis_date = datetime.now()
analysis_date = analysis_date.strftime("%Y-%m-%d")
plt.title(f"Sentiment Analysis of Tweets ({analysis_date}) for @CNN")
plt.xlim(-100,0) 
plt.ylim(-1,1) 
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.grid()
plt.savefig("cnn.png")
plt.show()

# %%
text_tweet = []
date_tweet = []
compound_list = []
positive_list = []
neutral_list = []
negative_list = []
tweets_ago = []
counter = 1
analyzer = SentimentIntensityAnalyzer()

target_account = "@FOXNews"
for x in range(1, 6):
    tweets = api.user_timeline(target_account, page=x)
    for tweet in tweets:

        text_tweet.append(tweet["text"])
        date_tweet.append(tweet["created_at"])
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]

        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)
        
        tweets_ago.append(counter)
        counter += 1

# %%
fox_df = pd.DataFrame({"Twitter Account":"@FoxNews",
                       "Tweet Date":date_tweet,
                       "Tweet":text_tweet,
                       "Compound":compound_list,
                       "Positive":positive_list,
                       "Neutral":neutral_list,
                       "Negative":negative_list,
                       "Tweets Ago":tweets_ago
                      })
fox_df=fox_df[["Twitter Account","Tweet Date","Tweet","Compound","Positive","Neutral","Negative","Tweets Ago"]]
fox_df.to_csv("fox.csv", sep=',', encoding='utf-8')
fox_df.head()
# Out:
#   Twitter Account                      Tweet Date  \
# 0        @FoxNews  Sat Jun 23 17:07:02 +0000 2018
# 1        @FoxNews  Sat Jun 23 17:00:01 +0000 2018
# 2        @FoxNews  Sat Jun 23 16:45:00 +0000 2018
# 3        @FoxNews  Sat Jun 23 16:38:45 +0000 2018
# 4        @FoxNews  Sat Jun 23 16:33:19 +0000 2018
#
#                                                Tweet  Compound  Positive  \
# 0  Moments ago, President @realDonaldTrump tweete...    0.3818     0.178
# 1  .@GovMikeHuckabee responds to his daughter @Pr...    0.0000     0.000
# 2  Sarah Sanders says she was thrown out of Virgi...    0.0000     0.000
# 3  ‘Despair and Hope in America: Fox News Investi...    0.7557     0.305
# 4  'Ashamed' @Comey weighs calling himself Canadi...    0.0000     0.000
#
#    Neutral  Negative  Tweets Ago
# 0    0.822       0.0           1
# 1    1.000       0.0           2
# 2    1.000       0.0           3
# 3    0.695       0.0           4
# 4    1.000       0.0           5

# %%
x_vals = fox_df["Tweets Ago"]
y_vals = fox_df["Compound"]
plt.plot(x_vals*-1,
         y_vals, marker="o", linewidth=0.25,
         alpha=0.8)


analysis_date = datetime.now()
analysis_date = analysis_date.strftime("%Y-%m-%d")
plt.title(f"Sentiment Analysis of Tweets ({analysis_date}) for @FOXTV")
plt.xlim(-100,0) 
plt.ylim(-1,1) 
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.grid()
plt.savefig("fox.png")
plt.show()

# %%
text_tweet = []
date_tweet = []
compound_list = []
positive_list = []
neutral_list = []
negative_list = []
tweets_ago = []
counter = 1
analyzer = SentimentIntensityAnalyzer()

target_account = "@NYTimes"
for x in range(1, 6):
    tweets = api.user_timeline(target_account, page=x)
    for tweet in tweets:

        text_tweet.append(tweet["text"])
        date_tweet.append(tweet["created_at"])
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]

        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)
        
        tweets_ago.append(counter)
        counter += 1

# %%
nyt_df = pd.DataFrame({"Twitter Account":"@NYTimes",
                       "Tweet Date":date_tweet,
                       "Tweet":text_tweet,
                       "Compound":compound_list,
                       "Positive":positive_list,
                       "Neutral":neutral_list,
                       "Negative":negative_list,
                       "Tweets Ago":tweets_ago
                      })
nyt_df=nyt_df[["Twitter Account","Tweet Date","Tweet","Compound","Positive","Neutral","Negative","Tweets Ago"]]
nyt_df.to_csv("nyt.csv", sep=',', encoding='utf-8')
nyt_df.head()
# Out:
#   Twitter Account                      Tweet Date  \
# 0        @NYTimes  Sat Jun 23 17:00:05 +0000 2018
# 1        @NYTimes  Sat Jun 23 16:45:12 +0000 2018
# 2        @NYTimes  Sat Jun 23 16:30:06 +0000 2018
# 3        @NYTimes  Sat Jun 23 16:15:03 +0000 2018
# 4        @NYTimes  Sat Jun 23 16:00:11 +0000 2018
#
#                                                Tweet  Compound  Positive  \
# 0  75% of Americans say immigration is good for t...    0.4404     0.116
# 1  Your weekend playlist has arrived https://t.co...    0.0000     0.000
# 2  As the driving ban gets lifted, Saudi women te...   -0.7351     0.000
# 3  ABC pulled the second episode of “The Proposal...   -0.2960     0.000
# 4  Here's where you can watch the world cup in NY...    0.5106     0.163
#
#    Neutral  Negative  Tweets Ago
# 0    0.884     0.000           1
# 1    1.000     0.000           2
# 2    0.763     0.237           3
# 3    0.891     0.109           4
# 4    0.837     0.000           5

# %%
x_vals = nyt_df["Tweets Ago"]
y_vals = nyt_df["Compound"]
plt.plot(x_vals*-1,
         y_vals, marker="o", linewidth=0.25,
         alpha=0.8)


analysis_date = datetime.now()
analysis_date = analysis_date.strftime("%Y-%m-%d")
plt.title(f"Sentiment Analysis of Tweets ({analysis_date}) for @NYT")
plt.xlim(-100,0) 
plt.ylim(-1,1) 
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.grid()

plt.savefig("nyt.png")
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.scatter(bbc_df["Tweets Ago"]*-1,
         bbc_df["Compound"],s=150,c="lightblue",  marker='o',
            edgecolor="black", linewidths=1, alpha=0.75, label="@BBC")
plt.scatter(cbs_df["Tweets Ago"]*-1,
         cbs_df["Compound"],s=150,c="green",  marker='o',
            edgecolor="black", linewidths=1, alpha=0.75, label="@CBS")
plt.scatter(cnn_df["Tweets Ago"]*-1,
         cnn_df["Compound"],s=150,c="red",  marker='o',
            edgecolor="black", linewidths=1, alpha=0.75, label="@CNN")
plt.scatter(fox_df["Tweets Ago"]*-1,
         fox_df["Compound"],s=150,c="blue",  marker='o',
            edgecolor="black", linewidths=1, alpha=0.75, label="@FOXTV")
plt.scatter(nyt_df["Tweets Ago"]*-1,
         nyt_df["Compound"],s=150,c="yellow",  marker='o',
            edgecolor="black", linewidths=1, alpha=0.75, label="@NYT")
analysis_date = datetime.now()
analysis_date = analysis_date.strftime("%Y-%m-%d")
plt.title(f"Sentiment Analysis of Tweets ({analysis_date})")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")
plt.legend(frameon= True,labelspacing= 0.9,bbox_to_anchor = (1.05,1),loc=2,borderaxespad=0.)
plt.xlim(-100,0)
plt.ylim(-1,1)
plt.grid(True)

plt.savefig("FinalAnalysis.png")
#Show plot
plt.show()

# %%
import numpy as np

bar_data_compound = []
bar_data_compound.append(bbc_df['Compound'].mean())
bar_data_compound.append(cbs_df['Compound'].mean())
bar_data_compound.append(cnn_df['Compound'].mean())
bar_data_compound.append(fox_df['Compound'].mean())
bar_data_compound.append(nyt_df['Compound'].mean())

# %%
bar_data_labels = ["@BBCNews","@CBSNews","@CNN","@FOXNews","@NYTimes"]
barChartData = {'Name':bar_data_labels,'Overall':bar_data_compound}
chart_df = pd.DataFrame(barChartData)
ax = plt.figure(figsize=(10,6)).add_subplot(111)

ax.patch.set_facecolor('whitesmoke')
ch = ax.bar(chart_df['Name'],chart_df['Overall'],width = 1,)

ch[0].set_color('lightblue')
ch[1].set_color('green')
ch[2].set_color('red')
ch[3].set_color('blue')
ch[4].set_color('yellow')
#Print out its value on each bar chart
for i in range(len(ch)):
        height = ch[i].get_height()
        value=  round(chart_df['Overall'][i],2)
        if height<0:
            height = height-0.032
        elif height>0:
            height = height+0.02
            value = f"+{value}"
        ax.text(ch[i].get_x() + ch[i].get_width()/2, 1*height,value,
                ha='center', va='bottom')
ax.set_title(f"Overall Media Sentiment based on Twitter({analysis_date})\n", fontsize = 16,fontweight="bold")
ax.set_ylim(-0.275,0.15)
ax.set_ylabel('Tweet Polarity',fontsize = 14)
plt.savefig("OverallMediaSentiment.png")
plt.show()

# %% [markdown]
# ## Analysis Notes
#
# 1. All networks results are on average negative in sentiment analysis performed.
# 2. BBC and CNN almost tied on the overall sentiments. Interesting results since these networks are in the oposite end of the spectrum in their point-of-view. BBC is considered conservative or right-wing and CNN is considered liberal or left-wing.
# 3. CBS News results were the most negative average sentiment.
