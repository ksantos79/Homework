# %%
import tweepy
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from config import consumer_key,consumer_secret ,access_token,access_token_secret

# %%
consumer_key = consumer_key
consumer_secret = consumer_secret
access_token = access_token
access_token_secret = access_token_secret

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

text_tweet = []
date_tweet = []
compound_list = []
positive_list = []
neutral_list = []
negative_list = []
tweets_ago = []
counter = 1
analyzer = SentimentIntensityAnalyzer()

target_account = "@BBC"
for x in range(1, 6):
    tweets = api.user_timeline(target_account, page=x)
    for tweet in tweets:

        text_tweet.append(tweet["text"])
        date_tweet.append(tweet["created_at"])
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]

        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)
        
        tweets_ago.append(counter)
        counter += 1

# %%
bbc_df = pd.DataFrame({"Twitter Account":"@BBC",
                       "Tweet Date":date_tweet,
                       "Tweet":text_tweet,
                       "Compound":compound_list,
                       "Positive":positive_list,
                       "Neutral":neutral_list,
                       "Negative":negative_list,
                       "Tweets Ago":tweets_ago
                      })
bbc_df=bbc_df[["Twitter Account","Tweet Date","Tweet","Compound","Positive","Neutral","Negative","Tweets Ago"]]
bbc_df.to_csv("bbc.csv", sep=',', encoding='utf-8')
bbc_df.head()
# Out:
#   Twitter Account                      Tweet Date  \
# 0            @BBC  Thu Jun 14 19:32:00 +0000 2018
# 1            @BBC  Thu Jun 14 19:03:07 +0000 2018
# 2            @BBC  Thu Jun 14 18:00:25 +0000 2018
# 3            @BBC  Thu Jun 14 16:00:21 +0000 2018
# 4            @BBC  Thu Jun 14 15:13:23 +0000 2018
#
#                                                Tweet  Compound  Positive  \
# 0  We're celebrating female voices and achievemen...    0.5719     0.163
# 1  Anne Robinson meets women from across the UK t...   -0.0258     0.000
# 2  'I'm glad you're in my life.'\n\n💕 How dementi...    0.4588     0.167
# 3  😂🦈  If you haven't seen @AlanDavies1's shark i...    0.2263     0.137
# 4  💚 Hundreds of people have taken part in a sile...   -0.2023     0.136
#
#    Neutral  Negative  Tweets Ago
# 0    0.837     0.000           1
# 1    0.948     0.052           2
# 2    0.833     0.000           3
# 3    0.863     0.000           4
# 4    0.699     0.165           5

# %%
x_vals = bbc_df["Tweets Ago"]
y_vals = bbc_df["Compound"]
plt.plot(x_vals*-1,
         y_vals, marker="o", linewidth=0.25,
         alpha=0.8)


analysis_date = datetime.now()
analysis_date = analysis_date.strftime("%Y-%m-%d")
plt.title(f"Sentiment Analysis of Tweets ({analysis_date}) for @BBC")
plt.xlim([x_vals.max()*-1,x_vals.min()]) 
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.grid()
plt.savefig("Images/bbc.png")
plt.show()

# %%
text_tweet = []
date_tweet = []
compound_list = []
positive_list = []
neutral_list = []
negative_list = []
tweets_ago = []
counter = 1
analyzer = SentimentIntensityAnalyzer()

target_account = "@CBS"
for x in range(1, 6):
    tweets = api.user_timeline(target_account, page=x)
    for tweet in tweets:

        text_tweet.append(tweet["text"])
        date_tweet.append(tweet["created_at"])
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]

        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)
        
        tweets_ago.append(counter)
        counter += 1

# %%
cbs_df = pd.DataFrame({"Twitter Account":"@CBS",
                       "Tweet Date":date_tweet,
                       "Tweet":text_tweet,
                       "Compound":compound_list,
                       "Positive":positive_list,
                       "Neutral":neutral_list,
                       "Negative":negative_list,
                       "Tweets Ago":tweets_ago
                      })
cbs_df=cbs_df[["Twitter Account","Tweet Date","Tweet","Compound","Positive","Neutral","Negative","Tweets Ago"]]
cbs_df.to_csv("cbs.csv", sep=',', encoding='utf-8')
cbs_df.head()
# Out:
#   Twitter Account                      Tweet Date  \
# 0            @CBS  Thu Jun 14 17:30:00 +0000 2018
# 1            @CBS  Thu Jun 14 16:19:32 +0000 2018
# 2            @CBS  Tue Jun 12 00:19:23 +0000 2018
# 3            @CBS  Mon Jun 11 22:23:06 +0000 2018
# 4            @CBS  Mon Jun 11 19:01:38 +0000 2018
#
#                                                Tweet  Compound  Positive  \
# 0  In case you missed it, watch the entire #TonyA...   -0.2960     0.000
# 1  RT @StrangeAngel: Mastermind or maniac? Explor...    0.1779     0.147
# 2  No pain, no gain, ALL Hart! Just one month unt...   -0.5562     0.134
# 3  RT @TheNeighborhood: Welcome to #TheNeighborho...    0.5093     0.171
# 4  In case you missed it, watch the entire #TonyA...   -0.2960     0.000
#
#    Neutral  Negative  Tweets Ago
# 0    0.833     0.167           1
# 1    0.734     0.120           2
# 2    0.551     0.315           3
# 3    0.829     0.000           4
# 4    0.833     0.167           5

# %%
x_vals = cbs_df["Tweets Ago"]
y_vals = cbs_df["Compound"]
plt.plot(x_vals*-1,
         y_vals, marker="o", linewidth=0.25,
         alpha=0.8)


analysis_date = datetime.now()
analysis_date = analysis_date.strftime("%Y-%m-%d")
plt.title(f"Sentiment Analysis of Tweets ({analysis_date}) for @CBS")
plt.xlim([x_vals.max()*-1,x_vals.min()]) 
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.grid()
plt.savefig("cbs.png")
plt.show()

# %%
text_tweet = []
date_tweet = []
compound_list = []
positive_list = []
neutral_list = []
negative_list = []
tweets_ago = []
counter = 1
analyzer = SentimentIntensityAnalyzer()

target_account = "@CNN"
for x in range(1, 6):
    tweets = api.user_timeline(target_account, page=x)
    for tweet in tweets:

        text_tweet.append(tweet["text"])
        date_tweet.append(tweet["created_at"])
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]

        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)
        
        tweets_ago.append(counter)
        counter += 1

# %%
cnn_df = pd.DataFrame({"Twitter Account":"@CNN",
                       "Tweet Date":date_tweet,
                       "Tweet":text_tweet,
                       "Compound":compound_list,
                       "Positive":positive_list,
                       "Neutral":neutral_list,
                       "Negative":negative_list,
                       "Tweets Ago":tweets_ago
                      })
cnn_df=cnn_df[["Twitter Account","Tweet Date","Tweet","Compound","Positive","Neutral","Negative","Tweets Ago"]]
cnn_df.to_csv("cnn.csv", sep=',', encoding='utf-8')
cnn_df.head()
# Out:
#   Twitter Account                      Tweet Date  \
# 0            @CNN  Fri Jun 15 01:53:03 +0000 2018
# 1            @CNN  Fri Jun 15 01:45:54 +0000 2018
# 2            @CNN  Fri Jun 15 01:45:40 +0000 2018
# 3            @CNN  Fri Jun 15 01:43:35 +0000 2018
# 4            @CNN  Fri Jun 15 01:41:56 +0000 2018
#
#                                                Tweet  Compound  Positive  \
# 0  The United States is putting its own economy a...   -0.3818     0.111
# 1  RT @CuomoPrimeTime: Sheriff Joe Arpaio on Trum...    0.0000     0.000
# 2  Sen. John McCain implicitly criticized Preside...   -0.3612     0.000
# 3  RT @CuomoPrimeTime: “Really… I mean Chris, com...   -0.2732     0.000
# 4  SpinLaunch, a Silicon Valley startup, has anno...    0.0000     0.000
#
#    Neutral  Negative  Tweets Ago
# 0    0.635     0.254           1
# 1    1.000     0.000           2
# 2    0.865     0.135           3
# 3    0.909     0.091           4
# 4    1.000     0.000           5

# %%
x_vals = cnn_df["Tweets Ago"]
y_vals = cnn_df["Compound"]
plt.plot(x_vals*-1,
         y_vals, marker="o", linewidth=0.25,
         alpha=0.8)


analysis_date = datetime.now()
analysis_date = analysis_date.strftime("%Y-%m-%d")
plt.title(f"Sentiment Analysis of Tweets ({analysis_date}) for @CNN")
plt.xlim([x_vals.max()*-1,x_vals.min()]) 
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.grid()
plt.savefig("cnn.png")
plt.show()

# %%
text_tweet = []
date_tweet = []
compound_list = []
positive_list = []
neutral_list = []
negative_list = []
tweets_ago = []
counter = 1
analyzer = SentimentIntensityAnalyzer()

target_account = "@FOXTV"
for x in range(1, 6):
    tweets = api.user_timeline(target_account, page=x)
    for tweet in tweets:

        text_tweet.append(tweet["text"])
        date_tweet.append(tweet["created_at"])
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]

        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)
        
        tweets_ago.append(counter)
        counter += 1

# %%
fox_df = pd.DataFrame({"Twitter Account":"@FOXTV",
                       "Tweet Date":date_tweet,
                       "Tweet":text_tweet,
                       "Compound":compound_list,
                       "Positive":positive_list,
                       "Neutral":neutral_list,
                       "Negative":negative_list,
                       "Tweets Ago":tweets_ago
                      })
fox_df=fox_df[["Twitter Account","Tweet Date","Tweet","Compound","Positive","Neutral","Negative","Tweets Ago"]]
fox_df.to_csv("cnn.csv", sep=',', encoding='utf-8')
fox_df.head()
# Out:
#   Twitter Account                      Tweet Date  \
# 0          @FOXTV  Fri Jun 15 00:04:38 +0000 2018
# 1          @FOXTV  Thu Jun 14 21:27:37 +0000 2018
# 2          @FOXTV  Thu Jun 14 20:31:07 +0000 2018
# 3          @FOXTV  Thu Jun 14 20:12:44 +0000 2018
# 4          @FOXTV  Thu Jun 14 20:10:42 +0000 2018
#
#                                                Tweet  Compound  Positive  \
# 0  Was @GordonRamsay able to save these kitchens ...   -0.2263     0.175
# 1  The gloves are OFF for Season 2 — tonight at 8...    0.0000     0.000
# 2  The @FIFAWorldCup has officially kicked off! O...   -0.4954     0.000
# 3  RT @GordonRamsay: The #WorldCup starts today o...    0.6239     0.163
# 4  Get your #WorldCup info straight from the pros...    0.6114     0.200
#
#    Neutral  Negative  Tweets Ago
# 0    0.601     0.224           1
# 1    1.000     0.000           2
# 2    0.841     0.159           3
# 3    0.837     0.000           4
# 4    0.800     0.000           5

# %%
x_vals = fox_df["Tweets Ago"]
y_vals = fox_df["Compound"]
plt.plot(x_vals*-1,
         y_vals, marker="o", linewidth=0.25,
         alpha=0.8)


analysis_date = datetime.now()
analysis_date = analysis_date.strftime("%Y-%m-%d")
plt.title(f"Sentiment Analysis of Tweets ({analysis_date}) for @FOXTV")
plt.xlim([x_vals.max()*-1,x_vals.min()]) 
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.grid()
plt.savefig("fox.png")
plt.show()

# %%
text_tweet = []
date_tweet = []
compound_list = []
positive_list = []
neutral_list = []
negative_list = []
tweets_ago = []
counter = 1
analyzer = SentimentIntensityAnalyzer()

target_account = "@NYT"
for x in range(1, 6):
    tweets = api.user_timeline(target_account, page=x)
    for tweet in tweets:

        text_tweet.append(tweet["text"])
        date_tweet.append(tweet["created_at"])
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]

        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)
        
        tweets_ago.append(counter)
        counter += 1

# %%
nyt_df = pd.DataFrame({"Twitter Account":"@NYT",
                       "Tweet Date":date_tweet,
                       "Tweet":text_tweet,
                       "Compound":compound_list,
                       "Positive":positive_list,
                       "Neutral":neutral_list,
                       "Negative":negative_list,
                       "Tweets Ago":tweets_ago
                      })
nyt_df=nyt_df[["Twitter Account","Tweet Date","Tweet","Compound","Positive","Neutral","Negative","Tweets Ago"]]
nyt_df.to_csv("cnn.csv", sep=',', encoding='utf-8')
nyt_df.head()
# Out:
#   Twitter Account                      Tweet Date  \
# 0            @NYT  Wed Jun 13 03:10:35 +0000 2018
# 1            @NYT  Wed Jun 13 02:57:35 +0000 2018
# 2            @NYT  Wed Jun 13 02:56:35 +0000 2018
# 3            @NYT  Wed Jun 13 02:55:36 +0000 2018
# 4            @NYT  Wed Jun 13 02:44:35 +0000 2018
#
#                                                Tweet  Compound  Positive  \
# 0  FIFA Set to Make $6.1 Billion From World Cup. ...    0.0000     0.000
# 1  Editorial: Trump Gambles and Loses on AT&amp;T...   -0.3182     0.000
# 2  On the Brink of Disaster in Yemen. https://t.c...   -0.6249     0.000
# 3  Yankees 3, Nationals 0: Didi Gregorius’s Power...    0.5859     0.226
# 4  Affordable Housing Is Your Spare Bedroom. http...    0.0000     0.000
#
#    Neutral  Negative  Tweets Ago
# 0    1.000     0.000           1
# 1    0.753     0.247           2
# 2    0.631     0.369           3
# 3    0.774     0.000           4
# 4    1.000     0.000           5

# %%
x_vals = nyt_df["Tweets Ago"]
y_vals = nyt_df["Compound"]
plt.plot(x_vals*-1,
         y_vals, marker="o", linewidth=0.25,
         alpha=0.8)


analysis_date = datetime.now()
analysis_date = analysis_date.strftime("%Y-%m-%d")
plt.title(f"Sentiment Analysis of Tweets ({analysis_date}) for @NYT")
plt.xlim([x_vals.max()*-1,x_vals.min()]) 
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.grid()

plt.savefig("nyt.png")
plt.show()

# %%
plt.scatter(bbc_df["Tweets Ago"]*-1,
         bbc_df["Compound"],s=150,c="red",  marker='o',
            edgecolor="black", linewidths=1, alpha=0.75, label="@BBC")
plt.scatter(cbs_df["Tweets Ago"]*-1,
         cbs_df["Compound"],s=150,c="blue",  marker='o',
            edgecolor="black", linewidths=1, alpha=0.75, label="@CBS")
plt.scatter(cnn_df["Tweets Ago"]*-1,
         cnn_df["Compound"],s=150,c="yellow",  marker='o',
            edgecolor="black", linewidths=1, alpha=0.75, label="@CNN")
plt.scatter(fox_df["Tweets Ago"]*-1,
         fox_df["Compound"],s=150,c="green",  marker='o',
            edgecolor="black", linewidths=1, alpha=0.75, label="@FOXTV")
plt.scatter(nyt_df["Tweets Ago"]*-1,
         nyt_df["Compound"],s=150,c="pink",  marker='o',
            edgecolor="black", linewidths=1, alpha=0.75, label="@NYT")
analysis_date = datetime.now()
analysis_date = analysis_date.strftime("%Y-%m-%d")
plt.title(f"Sentiment Analysis of Tweets ({analysis_date})")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")
plt.legend(frameon= True,labelspacing= 0.9,bbox_to_anchor = (1.05,1),loc=2,borderaxespad=0.)
plt.xlim(-100,0)
plt.ylim(-1,1)
plt.grid(True)
plt.savefig("FinalAnalysis.png")
#Show plot
plt.show()
